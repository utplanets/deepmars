# %%
import pylab as plt
import numpy as np
import tifffile
import pandas as pd
import os
import dotenv
project_dir = os.path.join(os.getcwd(), os.pardir)
dotenv_path = os.path.join(project_dir, '.env')
found = dotenv.load_dotenv(dotenv_path)

# %%
for k,v in os.environ.items():
    if k.startswith("DM"):
        print(k,v)
# Out:
# DM_ROOTDIR /Users/lee/Research/DeepLearning/MarsCraters/dm
# DM_CraterTable /Users/lee/Research/DeepLearning/MarsCraters/dm/data/raw/RobbinsCraters_20121016.tsv
# DM_MarsDEM /Users/lee/Research/DeepLearning/MarsCraters/dm/data/raw/Mars_HRSC_MOLA_BlendDEM_Global_200mp_v2.tif
# DM_SEED 14
# DM_KERAS_MODEL /Users/lee/Research/DeepLearning/MarsCraters/dm/data/models/model_keras2.h5

# %%
mola = tifffile.imread(os.path.join(os.getenv("DM_ROOTDIR"),"data/raw/Mars_HRSC_MOLA_BlendDEM_Global_200mp_v2.tif"))

# %%
plt.imshow(mola[::100,::100],cmap="Reds_r")
plt.show()

# %%
df = pd.read_table(os.path.join(os.getenv("DM_ROOTDIR"),"data/raw/RobbinsCraters_20121016.tsv"), sep='\t',engine='python')
df.head()
# Out:
#    CRATER_ID  LATITUDE_CIRCLE_IMAGE  LONGITUDE_CIRCLE_IMAGE  \
# 0  01-000000                 84.367                 108.746
# 1  01-000001                 72.760                 164.464
# 2  01-000002                 69.244                 -27.240
# 3  01-000003                 70.107                 160.575
# 4  01-000004                 77.996                  95.617
#
#    LATITUDE_ELLIPSE_IMAGE  LONGITUDE_ELLIPSE_IMAGE  DIAM_CIRCLE_IMAGE  \
# 0                  84.750                  108.663              82.10
# 1                  72.784                  164.464              82.02
# 2                  69.241                  -27.235              79.63
# 3                  70.151                  160.575              74.81
# 4                  77.998                   95.615              73.53
#
#    DIAM_CIRCLE_SD_IMAGE  DIAM_ELLIPSE_MAJOR_IMAGE  DIAM_ELLIPSE_MINOR_IMAGE  \
# 0                  0.26                     82.97                     69.43
# ...
